# %%
import pandas as pd
df = pd.read_csv('student-mat.csv', sep=";")
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

students_data = pd.read_csv('student-mat.csv', sep=";")
students_data = students_data[["G1","G2","G3","studytime","failures","absences",]]

X = students_data.iloc[:,:-1].values
y = students_data.iloc[:,1].values

sns.barplot(x='G1', y='failures', data=students_data)
# Out:
# <Axes: xlabel='G1', ylabel='failures'>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

students_data = pd.read_csv('student-mat.csv', sep=";")
students_data = students_data[["G1","G2","studytime","failures","absences","G3"]]

X = students_data.drop(columns=['G3'])
y = students_data['G3']

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.1)

from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train.values, y_train)
lr.score(X_test.values, y_test)

#lr.predict([[5,10,3,0,0],[19,17,6,0,0]])
# Out:
# 0.8537109255706108

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

students_data = pd.read_csv('student-mat.csv', sep=";")
students_data = students_data[["G1","G2","studytime","failures","absences","G3"]]

X = students_data.drop(columns=['G3'])
y = students_data['G3']

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.1)

from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train.values, y_train)

predictions = lr.predict(X_test.values)

for x in range(len(predictions)):
    #predictions[X], X_test[X], y_test[X]
    print(f"Prediction: {predictions[x]}, Inputs: {X_test.values[x]}, Actual: {y_test.values[x]}")
# Out:
# Prediction: 8.502977468774386, Inputs: [8 9 2 0 8], Actual: 10
# Prediction: 10.945076645785637, Inputs: [13 11  2  0  2], Actual: 11
# Prediction: 7.7253750102152665, Inputs: [ 9  8  2  0 10], Actual: 8
# Prediction: 9.645194784345971, Inputs: [11 10  3  0  4], Actual: 11
# Prediction: 9.253333283163201, Inputs: [ 9  9  1  0 22], Actual: 9
# Prediction: 8.267129221411148, Inputs: [10  9  4  0  0], Actual: 0
# Prediction: 6.3120299715830495, Inputs: [8 7 1 1 7], Actual: 8
# Prediction: 11.944280822875822, Inputs: [11 12  2  0 10], Actual: 13
# Prediction: 7.432372805349884, Inputs: [5 9 2 2 6], Actual: 7
# Prediction: 15.450818492518014, Inputs: [15 15  2  0 10], Actual: 15
# Prediction: 5.087646680217951, Inputs: [6 7 2 3 0], Actual: 0
# Prediction: 11.905837543567133, Inputs: [12 12  1  0  2], Actual: 14
# Prediction: 10.605955682127462, Inputs: [10 11  2  0  4], Actual: 9
# Prediction: 12.022059645816467, Inputs: [15 12  3  0  0], Actual: 14
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

students_data = pd.read_csv('student-mat.csv', sep=";")
students_data = students_data[["G1","G2","studytime","failures","absences","G3"]]

X = students_data.drop(columns=['G3'])
y = students_data['G3']

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.1)

from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train.values, y_train)

predictions = lr.predict(X_test.values)

plt.figure(figsize=(10, 7))
plt.scatter(y_test.values, predictions, alpha=0.5)
plt.plot([min(y_test.values), max(y_test.values)], [min(y_test.values), max(y_test.values)], color='red', linestyle='-', linewidth=1)
plt.title('Actual vs Predicted')
plt.xlabel('Actual values')
plt.ylabel('Predicted values')
plt.show()
